# %%
continuation with string data type:

# %%
introduction to f - strings:

# %%
firstname = 'Sirisha'
lastname = 'MV'

# %%
# requirement : i want to get the full name...?

# %%
#general syntax to strings...?

# %% [markdown]
# message = f" custom message {placeholder1} {placeholder2}..... {placeholdern}"

# %%
fullname = f"{firstname} {lastname}"
print(fullname)
# Out:
# Sirisha MV

# %%
print(fullname.title())
# Out:
# Sirisha Mv

# %%
message = f"Keep up the good work, {fullname.title()}."
print(message)
# Out:
# Keep up the good work, Sirisha Mv.

# %%
understanding the concept of whitespaces:

# %%
print("Fav_prog:PythoncJavaC++swiftjavascript")
# Out:
# Fav_prog:PythoncJavaC++swiftjavascript

# %%
print("Fav_prog:\nPython\nc\nJava\nC++\nswift\njavascript")
# Out:
# Fav_prog:
# Python
# c
# Java
# C++
# swift
# javascript

# %%
\n ---> new line delimiter

# %%
print("Fav_prog:\n\tPython\n\tc\n\tJava\n\tC++\n\tswift\n\tjavascript")
# Out:
# Fav_prog:
# 	Python
# 	c
# 	Java
# 	C++
# 	swift
# 	javascript

# %%
\t ---> tab delimiter

# %%
eliminating white spaces :

# %%
name = ' Python'
print(name)
# Out:
#  Python

# %%
name2 = 'python '
print(name2)
# Out:
# python

# %%
name3 ='python'
print(name3)
# Out:
# python

# %%
name.lstrip()  #leftstrip
# Out:
# 'Python'

# %%
name2.rstrip()  #rightstrip
# Out:
# 'python'
