# %%
introduction to python fundamentals

# %%
understanding the variables in python

# %%
a=2
b=3

# %%
c = a+b

print(c)
# Out:
# 5

# %%
rules for declaring variables in python

# %%
Rule 1 : no name spaces while declaring the variable name

# %%
first name = 'Sirisha'
# Out:
#   Cell In[5], line 1
#     first name = 'Sirisha'
#           ^
# SyntaxError: invalid syntax

# %%
firstname ='Sirisha'
print(firstname)
# Out:
# Sirisha

# %%
Rule 2: Variable name should not start with number.**

# %%
1name = 'Teja'
print(iname)
# Out:
#   Cell In[7], line 1
#     1name = 'Teja'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'Teja'
print(name1)
# Out:
# Teja

# %%
Rule 3: a variable should not contain any special characters

# %%
test@ = 'Siri'
print(test@)
# Out:
#   Cell In[9], line 1
#     test@ = 'Siri'
#           ^
# SyntaxError: invalid syntax

# %%
test = 'Siri'
print(test)
# Out:
# Siri

# %%
introduction to data types in python
    1. strings --> str
    2. numbers --> integers-->(int) and decimals(float)
    3.list
    4.tuple
    5.dictionary

# %%
classification of data types:
    broadly data types are classified into  2 categories
    1. mutable - which can be edited/altered - flexible in nature
    2. immutable - which cannot be edited/altered - fixed in nature

# %%
intoduction to string data types

# %%
definition: a string is nothing but a sequence of characters written in quotes.

classification: it is calssified as an immutable datatype

how to declare the string?
approach 1: using single quote
approach 2: using double quote

# %%
name = 'Sreema' #single quote
print(name)
# Out:
# Sreema

# %%
name2 = 'Karthik' #doublr quote
print(name2)
# Out:
# Karthik

# %%
introduction to string methods: methods are like function that are pre built in python

# %%
type(name)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
fullname = 'venkata sirisha'
print(fullname)
# Out:
# venkata sirisha

# %%
#requiremet 1: how o correct format

# %%
print(fullname.title())
# Out:
# Venkata Sirisha

# %%
#req: i want the entire name in upper case

# %%
print(fullname.upper())
# Out:
# VENKATA SIRISHA

# %%
#req: i want the entire name in lower case

# %%
print(fullname.lower())
# Out:
# venkata sirisha
