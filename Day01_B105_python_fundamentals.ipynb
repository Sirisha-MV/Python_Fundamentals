# %%
print("Hello World")
# Out:
# Hello World

# %%
print("22nd spetember 2026, day one of python fundamentals, hopefully i will gain a good knowledge in python in the next 30 days")
# Out:
# 22nd spetember 2026, day one of python fundamentals, hopefully i will gain a good knowledge in python in the next 30 days
