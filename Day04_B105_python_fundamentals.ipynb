# %%
introduction to list datatype:

# %%
definition: a list is a collection of items declared in a particular order

classification: it is classified as mutable datatype

how to declare the list datatype --->  []

# %%
students = ["akhila", "divya", "Sirisha","teja", "akhil", "satya", "shruti"] # 0,1,2,3,4,5,6

# %%
print(students)
# Out:
# ['akhila', 'divya', 'Sirisha', 'teja', 'akhil', 'satya', 'shruti']

# %%
type(students)
# Out:
# list

# %%
introduction to indexing: 0,1,2,3,4,......

# %%
# to access divya name in the output
print(students[1])
# Out:
# divya

# %%
# to access teja name in the output
print(students[3])
# Out:
# teja

# %%
1. how to add new elements to the list -- 
2. how to modify the elements in the list
3. how to delete the elements in the list

# %%
# req: i want to add akash to the list

# %%
students.append("akash")

# %%
print(students)
# Out:
# ['akhila', 'divya', 'Sirisha', 'teja', 'akhil', 'satya', 'shruti', 'akash']

# %%
students.append("Ravi")

# %%
print(students)
# Out:
# ['akhila', 'divya', 'Sirisha', 'teja', 'akhil', 'satya', 'shruti', 'akash', 'Ravi']

# %% [raw]
# # append is list method which lets you add elements in a list at the end of the list, any new data or element updated using

# %%
# req : to add manasa in 2nd index

# %%
students.insert(2,"manasa")

# %%
print(students)
# Out:
# ['akhila', 'divya', 'manasa', 'Sirisha', 'teja', 'akhil', 'satya', 'shruti', 'akash', 'Ravi']

# %%
interview_question:

what is the difference between append and insert method in list data type, please explain? **
append is used to add elements at the end of the list, while with insert we can elements at the desired index.

# %%
# req: i want to modify divya to sana

# %%
students [1] = "sana"

# %%
print(students)
# Out:
# ['akhila', 'sana', 'manasa', 'Sirisha', 'teja', 'akhil', 'satya', 'shruti', 'akash', 'Ravi']

# %%
# req : want to delete sirisha

# %%
del students[3]

# %%
print(students)
# Out:
# ['akhila', 'sana', 'manasa', 'teja', 'akhil', 'satya', 'shruti', 'akash', 'Ravi']
